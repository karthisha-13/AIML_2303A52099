# %% [markdown]
# <a href="https://colab.research.google.com/github/karthisha-13/AIML_2303A52099/blob/main/Lab_01_AIML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Part 3 – Access Data from Various Data Sources using builtin Function of Numpy, Pandas[CO3]
# 1. Generate your own dataset using MS Excel and Notepad to prepare the dataset. Save
# it in Google Drive and access it in Google Colab.
# 2. Upload the text file using tab seperated value(.tsv) and access the data from the file.
# 3. Upload the text file using comma seperated value(.csv) and access the data from file.
# 4. Access the excel file using .xlsx
# 5. Access the text from the URL

# %%
import numpy as np
import pandas as pd

# %%
df1 = pd.read_table("/content/drive/MyDrive/2099/self introduction.txt")

# %%
df1
# Out:
# Empty DataFrame
# Columns: [Hi,I'm Karthisha.I'm studying btech in sr University .]
# Index: []

# %%
data2 =pd.read_excel("/content/drive/MyDrive/2099/Details.xlsx")

# %%
data2
# Out:
#    S.NO    NAME CLASS  BATCH  H.NO
# 0     1  karthi  aiml     33  2099
# 1     2    navs   cse     19  1244
# 2     3   vyshu   cse     29  1554
# 3     4   suppu   ece      1  1100

# %%
data3 =pd.read_csv("/content/drive/MyDrive/2099/csv.notepad.csv")

# %%
data3
# Out:
#              hai
# 0          hello
# 1   good morning
# 2  i'm Karthisha
